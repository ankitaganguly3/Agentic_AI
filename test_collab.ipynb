# %%
print("hello world");
# Out:
# hello world

# %%
print("Hello Tuli");
# Out:
# Hello Tuli

# %% [markdown]
# Markdown -> This is just to enter text . It is non executable .

# %%
print("hello world")
# Out:
# hello world

# %%
print("ankita")
# Out:
# ankita

# %%
import platform
print(platform.python_version())
# Out:
# 3.11.4
